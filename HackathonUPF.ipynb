# %%
from collections import defaultdict
import pandas as pd

# Read CSV file
file_path = "Mov preparacion 02.2025.csv"
df = pd.read_csv(file_path)

# Clean column names (remove spaces)
df.columns = df.columns.str.strip()

# Filter rows:
df = df[~df["Ubic.proc."].astype(str).str.startswith("4")]
df = df[df["Ubic.proc."].astype(str).str.endswith("10")]

# Ensure 'CtdTeóricaDesde' is numeric
df["CtdTeóricaDesde"] = pd.to_numeric(df["CtdTeóricaDesde"], errors="coerce")

# Total unique products
total_products = df["Material"].nunique()

# Create base tuples
matrix_data = list(zip(df["Material"], df["CtdTeóricaDesde"], df["Texto breve de material"], df["Ubic.proc."]))

# Group by material
grouped_data = defaultdict(lambda: [0, 0, "", ""])
for material, quantity, description, location in matrix_data:
    if pd.notnull(quantity):
        grouped_data[material][0] += quantity
        grouped_data[material][1] += 1
        grouped_data[material][2] = description
        grouped_data[material][3] = location

# Construction and initial sorting by frequency and quantity
grouped_matrix = [
    (material, total, count / total_products, desc, loc)
    for material, (total, count, desc, loc) in grouped_data.items()
]
grouped_matrix.sort(key=lambda x: (x[2], x[1]), reverse=True)

# Extract original locations
extracted_locations = [loc for _, _, _, _, loc in grouped_matrix]

# Custom sorting functions
def get_sub_block(location):
    try:
        return int(location.split('-')[1])
    except:
        return 999

def filter_and_sort(location_list, prefix, max_value=None, condition='<='):
    result = []
    for loc in location_list:
        if loc.startswith(prefix):
            value = get_sub_block(loc)
            if max_value is None or (condition == '<=' and value <= max_value) or (condition == '>' and value > max_value):
                result.append(loc)
    return sorted(result, key=lambda x: get_sub_block(x))

# Apply sorting rules
sorted_locations = []
sorted_locations += filter_and_sort(extracted_locations, "600", 48, "<=")
sorted_locations += filter_and_sort(extracted_locations, "620")
sorted_locations += filter_and_sort(extracted_locations, "660", 43, "<=")
sorted_locations += filter_and_sort(extracted_locations, "680", 43, "<=")
sorted_locations += filter_and_sort(extracted_locations, "600", 48, ">")
sorted_locations += filter_and_sort(extracted_locations, "630")
sorted_locations += filter_and_sort(extracted_locations, "660", 43, ">")
sorted_locations += filter_and_sort(extracted_locations, "680", 43, ">")
sorted_locations += filter_and_sort(extracted_locations, "690")
sorted_locations = list(dict.fromkeys(sorted_locations))

# Assignment of ordered locations
final_products = []
for (material, total, frequency, desc, _), new_location in zip(grouped_matrix, sorted_locations):
    final_products.append([material, total, frequency, desc, new_location])

# -------------------------
# CORRECTED RELOCATION LOGIC (ONLY CHANGE LOCATIONS)
# -------------------------

def parse_location(location):
    parts = location.split("-")
    return parts[0], int(parts[1]), parts[2]

def contains_brand(description, brands):
    description_upper = description.upper()
    return any(brand in description_upper for brand in brands)

key_brands = ["GRANINI", "JUVER", "MINUTE MAID"]

# First pass: Identify all conflicts
conflicts = []
for i in range(len(final_products)):
    current_material, _, _, current_description, current_location = final_products[i]
    current_block, current_zone, _ = parse_location(current_location)

    if not contains_brand(current_description, key_brands):
        continue

    # Search for conflicts in close neighbors
    for offset in [-2, -1, 1, 2]:
        j = i + offset
        if 0 <= j < len(final_products):
            neighbor_material, _, _, neighbor_description, neighbor_location = final_products[j]
            neighbor_block, neighbor_zone, _ = parse_location(neighbor_location)

            if (current_block == neighbor_block and
                abs(current_zone - neighbor_zone) == 2 and
                contains_brand(neighbor_description, key_brands)):

                # Register conflict (smaller index first to avoid duplicates)
                conflicts.append(tuple(sorted((i, j))))

# Remove duplicates
conflicts = list(set(conflicts))

# Second pass: Resolve conflicts by exchanging only locations
for i, j in conflicts:
    # Find non-conflicting neighbor to exchange locations
    for swap_offset in [-1, 1]:
        swap_index = i + swap_offset
        if (0 <= swap_index < len(final_products)) and not contains_brand(final_products[swap_index][3], key_brands):
            # Exchange ONLY the locations
            final_products[i][4], final_products[swap_index][4] = final_products[swap_index][4], final_products[i][4]
            break
    else:
        # If no suitable neighbor found, try with the other end
        for swap_offset in [-1, 1]:
            swap_index = j + swap_offset
            if (0 <= swap_index < len(final_products)) and not contains_brand(final_products[swap_index][3], key_brands):
                # Exchange ONLY the locations
                final_products[j][4], final_products[swap_index][4] = final_products[swap_index][4], final_products[j][4]
                break

# -------------------------
# SHOW FINAL RESULTS
# -------------------------

print("\nRelocated matrix (only locations were changed to resolve conflicts):\n")
print(f"Total different products: {total_products}\n")
print("{:<10} {:<10} {:<20} {:<30} {:<15}".format("Material", "Quantity", "Frequency", "Description", "Location"))
print("-" * 85)
for material, total, freq, desc, location in final_products:
    print("{:<10} {:<10.1f} {:<20.4f} {:<30} {:<15}".format(material, total, freq, desc[:28], location))

# Optional: Save results to CSV
result_df = pd.DataFrame(final_products,
                        columns=["Material", "Quantity", "Frequency", "Description", "Location"])
result_df.to_csv("relocation_results_corrected.csv", index=False)
# Out:
# Relocated matrix (only locations were changed to resolve conflicts):
#
# Total different products: 381
#
# Material   Quantity   Frequency            Description                    Location
# -------------------------------------------------------------------------------------
# 0RF0161    9475.0     1.4961               COCACOLA LATA33 C24 (SIN HC8   600-004-10
# 0LT0235    1692.0     1.4803               LA LEVANTINA AVENA ESP.HOST    600-006-10
# 0RF0187    10777.0    1.4593               COCACOLA ZER LATA33 C24 (SIN   600-007-10
# 0LT0090    1148.0     1.2756               LETONA SEMI SIN LACTOSA 1L P   600-008-10
# ED13LT     1594.0     1.2598               ESTRELLA DAMM 1/3 LATA         600-009-10
# EC13P6     929.0      1.1339               DAURA DAMM 1/3 SR PACK CESTA   600-011-10
# 0LT0034    2542.0     1.0420               LETONA SEMI ESPEC HOSTELERIA   600-012-10
# 0ZU0020    686.0      1.0184               GRANINI MELOCOTON  20CL 24U    600-013-10
# 0ZU0024    680.0      1.0105               GRANINI PIÑA 20CL 24U          600-017-10
# 0LT0036    729.0      0.9239               CACAOLAT VIDRIO 20CL SR 24U    600-019-10
# FTI15B24   1703.0     0.9213               FEVERTREE INDIAN TONIC 1/5 B   600-020-10
# 0LT0412    1763.0     0.9003               CACAOLAT ORIGINAL 27,5CL PET   600-021-10
# 0AM3565    1792.0     0.8871               BARGALLO ACEITE GOURMET SOL    600-022-10
# NTL13LT6   2478.0     0.8714               NESTEA LIMON 1/3 LATA 4U-PAC   600-023-10
# 0RF0019    974.0      0.8556               /-COCA COLA LATA 33CL 24U      600-024-10
# 0VE0524    875.0      0.8451               SEÑORIO DE LIZIA VERDEJO RUE   600-025-10
# 0RF0115    824.0      0.8346               AQUARIUS LATA33 C24            600-026-10
# 0RF0508    720.0      0.8163               FANTA NAR LATA33 24U (SIN HC   600-027-10
# 0RF0252    2982.0     0.7612               COCACOLA PET50 C24 (SIN HC4)   600-028-10
# 0RF0079    985.0      0.7454               /-COCA COLA ZERO LATA 33CL 2   600-029-10
# 0ZU0021    408.0      0.7349               GRANINI NARANJA 20CL 24U       600-030-10
# 0AM5080    911.0      0.7270               CACAOLAT PASTELITOS 20U        600-031-10
# 0RF0080    5373.0     0.7034               COCACOLA ZER PET50 C24 (SIN    600-032-10
# 0LT0103    836.0      0.6850               YOSOY AVENA BARISTA 1L BRIK    600-033-10
# NTL13B24   600.0      0.6588               NESTEA LIMON 1/3 SR BANDEJA    600-034-10
# 0AG0310    1007.0     0.6535               VICHY CATALAN GAS 30CL SR 24   600-035-10
# 0RF1646    823.0      0.6430               FUZE LIM LATA33 CCO8 C24       600-036-10
# 0RF0114    472.0      0.6325               FANTA LIM LATA33 C24           600-037-10
# 0LT0035    594.0      0.6299               LETONA DESNATADA 0% HOST 1,5   600-038-10
# 0AM3864    480.0      0.6299               FRIMASOL ACEITE GIRASOL 25L    600-039-10
# 0LT0234    367.0      0.6247               LA LEVANTINA SOJA ESPECIAL H   600-040-10
# 0RF0332    697.0      0.6089               ZALA GASEOSA 50CL S/R 12U      600-041-10
# 0RF0296    1036.0     0.6063               RED BULL ENERGY DRINK 25CL L   600-042-10
# 0CF0080    1243.0     0.5853               XPLICIT NATURAL CREMOSO 1KG    600-043-10
# 0RF0287    554.0      0.5696               /-COCA COLA VR237 24U          600-044-10
# 0AG0107    3000.0     0.5617               EUROACQUA NATURAL 8L GARRAFA   600-045-10
# 0RF0445    511.0      0.5433               GEISER LIMONADA 2L SR 6U       600-046-10
# 0VE0506    1050.0     0.5381               HALLAZGO JOVEN 75CL 6U         600-047-10
# FTB15B24   619.0      0.5354               FEVERTREE GINGER BEER 1/5 BA   600-048-10
# 0RF0048    417.0      0.5328               COCACOLA PET2L C6              620-001-10
# 0RF0053    603.0      0.5223               NORDIC MIST TON VR20 C24       620-002-10
# 0AG0014    3088.0     0.5197               AQUABONA PET50 C24             620-003-10
# 0RF0112    1385.0     0.5197               COCACOLA LATA33 C24            620-004-10
# 0RF0181    778.0      0.5144               SPRITE VR20 C24                620-005-10
# 0RF0173    490.0      0.5118               FANTA LIM PET2L C6             620-006-10
# CM13P6     321.0      0.5092               COMPLOT 1/3 SR PACK CESTA AB   620-007-10
# 0AM1634    292.0      0.4987               XPLICIT EDULCORANTE 1G 150U    620-008-10
# 0RF0489    367.0      0.4908               SCHWEPPES TONICA 20CL SR 24U   620-009-10
# 0RF0059    632.0      0.4882               AQUARIUS PET50 C24             620-010-10
# 0AM1290    282.0      0.4882               XPLICIT AZUCAR 7GR  1000U      620-011-10
# FD13LT     259.0      0.4856               FREE DAMM 1/3 LATA LC          620-012-10
# 0RF0199    306.0      0.4541               COCACOLA ZER ZER VR35 C24      620-013-10
# 0RF0022    261.0      0.4514               /-AQUARIUS LIMON 33CL LATA 2   620-014-10
# ED13SR     4028.0     0.4409               ESTRELLA DAMM 1/3 SIN RETORN   620-015-10
# VE51SP     599.0      0.4383               AGUA VERI 5/1 CAJA 3U.         620-016-10
# 0RF0184    238.0      0.4304               SPRITE VR35 C24                620-017-10
# 0RF0208    601.0      0.4278               FANTA NAR PET50 C24 (SIN HC4   620-018-10
# 0RF0109    193.0      0.4199               /-BITTER KAS 200 SR 24U        620-019-10
# 0AG0001    3566.0     0.4173               AQUABONA PET1.5L C6 DECORADA   620-020-10
# 0RF0200    437.0      0.4016               /-COCA COLA ZERO VR 23,7 24U   620-021-10
# 0AM1167    534.0      0.3937               MARINAS PATATAS OLIVA 47G  1   620-022-10
# 0VE0503    489.0      0.3885               VINYA DEL JEP TINTO 75CL 6U    620-023-10
# 0ZU0133    398.0      0.3832               MINUTE MAID PIÑ VNR20 C24      620-024-10
# 0VE0463    510.0      0.3648               SOLAR DE ZUNIL TINTO 75CL 6U   620-025-10
# 0RF0185    299.0      0.3596               SPRITE LATA33 C24              620-026-10
# 0RF0041    287.0      0.3465               COCACOLA PET1L C12             620-027-10
# 0VE1410    253.0      0.3333               ALLUE CAVA BRUT NATURE 75CL    620-028-10
# 0ZU0134    266.0      0.3307               MINUTE MAID MEL VNR20 C24      620-029-10
# 0RF0004    214.0      0.3071               GEISER SIFON  1,5 L. 6U        620-030-10
# 0RF0020    156.0      0.3045               /-FANTA NARANJA LATA 33CL 24   620-031-10
# 0RF1648    658.0      0.2940               FUZE LIM PET1.5L C6            620-032-10
# 0VE0973    246.0      0.2913               FINCA LOS TRENZONES VERDEJO    620-033-10
# 0RF0052    410.0      0.2861               FANTA LIM PET50 C24 (SIN HC4   620-034-10
# 0RF0120    236.0      0.2861               AQUARIUS NAR LATA33 C24        620-035-10
# 0RF0211    346.0      0.2808               MONSTER ENERGY LATA50 C24      620-036-10
# 0AG0050    627.0      0.2782               FONT DEL REGAS NATURAL 8L GA   620-038-10
# 0ZU0026    234.0      0.2730               GRANINI MANZANA  20CL 24U      620-037-10
# 0ZU0135    158.0      0.2730               MINUTE MAID NAR VNR20 C24      620-039-10
# 0ZU0013    207.0      0.2703               GRANINI PIÑA 1L PET 6U         620-040-10
# 0RF0230    426.0      0.2651               RBLISS SIG TON WTR VR20 C24    620-041-10
# NTL32SP6   6543.0     0.2598               NESTEA LIMON 3/2 SR PET 6U.    620-042-10
# 0RF0062    437.0      0.2598               POWERADE ICE STORM PET50 C12   660-001-10
# 0AM4158    570.0      0.2572               SABOR DEL SUR ACEITE VIRGEN    660-002-10
# 0RF0138    401.0      0.2546               COCACOLA ZER PET2L C6          660-003-10
# 0RF0058    273.0      0.2546               AQUARIUS NAR PET50 C24         660-004-10
# 0RF0110    231.0      0.2520               AQUARIUS PET1.5L C6            660-005-10
# 0RF0141    482.0      0.2493               COCACOLA ZER ZER LATA33 C24    660-006-10
# 0RF0183    338.0      0.2467               SPRITE PET50 C24               660-007-10
# 0VE0507    196.0      0.2467               HALLAZGO CRIANZA 75CL 6U       660-008-10
# 0ZU0010    204.0      0.2441               GRANINI NARANJA 1L PET 6U      660-009-10
# 0AG0018    2575.0     0.2388               AQUABONA PET35 C24             660-010-10
# 0RF0119    634.0      0.2388               COCACOLA ZER LATA33 C24        660-011-10
# 0AG0060    202.0      0.2388               SAN PELLEGRINO GAS 1/4 SR 24   660-012-10
# UE902CATN  9378.0     0.2362               COPA 33 CL ED CAT              660-013-10
# 0AG0067    256.0      0.2362               SAN PELLEGRINO GAS 1/2 SR 24   660-014-10
# AK13SR     183.0      0.2283               AK DAMM 1/3 SIN RETORNO        660-015-10
# 0AG0085    169.0      0.2283               SAN PELLEGRINO GAS 1/2 PET 2   660-016-10
# 0LT0102    145.0      0.2283               YOSOY AVENA 1L BRIK 6U         660-017-10
# 0RF0243    322.0      0.2257               MONSTER ULTR WHI ZER LATA50    660-018-10
# 0VE0504    164.0      0.2231               VINYA DEL JEP BLANCO 75CL 6U   660-019-10
# 0RF0197    354.0      0.2205               COCACOLA ZER ZER VR237 C24     660-020-10
# FTG15B24   210.0      0.2205               FEVERTREE GINGER ALE 1/5 BJ-   660-021-10
# 0AG0022    611.0      0.2178               VICHY 1881 GAS 1/3 RET 20U     660-022-10
# 0RF0313    162.0      0.2152               MONSTER MANGO LOCO LATA50 C2   660-023-10
# 0AM1282    249.0      0.2126               BARGALLO OLI GIRASOL 5L        660-024-10
# 0AG0092    436.0      0.2100               MALAVELLA AGUA CON GAS 30CL    660-025-10
# 0VE0106    194.0      0.2100               PORTIA ROBLE 75CL 6U           660-027-10
# 0RF0136    144.0      0.2100               COCACOLA ZER PET1L C12         660-029-10
# 0RF0111    229.0      0.2073               AQUARIUS NAR PET1.5L C6        660-030-10
# 0RF0339    348.0      0.2021               NORDIC MIST TON VNR20 C24      660-031-10
# 0VE0092    242.0      0.2021               FORTIUS TINTO TEMPRANILLO 75   660-032-10
# 0RF0021    89.0       0.2021               /-FANTA LIMON LATA 33 CL 24U   660-033-10
# FTS15B24   221.0      0.1995               FEVERTREE SODA WATER 1/5 BAN   660-034-10
# 0RF0172    131.0      0.1995               FANTA NAR PET2L C6             660-035-10
# FD14P6     187.0      0.1969               FREE DAMM 1/4 PACK 6U.         660-036-10
# 0RF0228    443.0      0.1890               RBLISS TON WTR VR20 C24        660-038-10
# 0RF0478    329.0      0.1890               COCACOLA ZER BIB10L            660-039-10
# 0AG0017    430.0      0.1837               AQUABONA VR50 C20              660-040-10
# 0RF0113    119.0      0.1837               FANTA NAR LATA33 C24           660-041-10
# GCN1KB6    711.0      0.1811               GARRIGA CREME NATURAL BOLSA    660-042-10
# 0RF1669    370.0      0.1785               FUZE GTM PET1.5L C6            660-043-10
# VO13P6     202.0      0.1759               VOLL DAMM 1/3 SR PACK CESTA    680-002-10
# OL20       170.0      0.1759               ORO BARRIL 20L. RET            680-004-10
# 0LT0100    86.0       0.1759               YOSOY SOJA 1L BRIK 6U          680-006-10
# 0VE0465    173.0      0.1732               SOLAR DE ZUNIL BLANCO 75CL 6   680-008-10
# 0AM1281    258.0      0.1706               BARGALLO OLIVA SANSA SUAVE 5   680-010-10
# 0RF0038    104.0      0.1680               SPRITE PET2L C6                680-012-10
# 0VE0543    233.0      0.1654               IRREVERENTE TINTO ROBLE 75CL   680-014-10
# 0RF0014    129.0      0.1627               ZALA GASEOSA 50CL VID. RET 2   680-015-10
# 0LT0021    262.0      0.1601               CACAOLAT MINIBRIK SLIM 20CL    680-016-10
# 0VE0625    119.0      0.1601               CONDESA LEGANZA BLANCO VERDE   680-017-10
# EDI13P6    116.0      0.1575               INEDIT DAMM 1/3 SR CESTA ABI   680-018-10
# 0RF1650    95.0       0.1575               FUZE GTM VR30 C24              680-019-10
# 0RF0233    421.0      0.1549               RBLISS LEM MIX VR20 C24 HT     680-020-10
# 0AM1278    153.0      0.1549               BARGALLO ACEITE VIRGEN EXTRA   680-021-10
# 0VE0198    109.0      0.1549               MONTERIO TINTO S.R. 75CL 12U   680-022-10
# 0AM1276    226.0      0.1522               BARGALLO ACEITE OLIVA SUAVE    680-023-10
# GD500B6    156.0      0.1522               GARRIGA DESCAFEINADO 500G BO   680-024-10
# 0AM1285    120.0      0.1522               BARGALLO RUGIN ACEITE FREIR    680-025-10
# 0AG0181    243.0      0.1496               FONT D.OR NATURAL 30CL RET 2   680-026-10
# 0AM1280    197.0      0.1496               BARGALLO ACEITE DE ORUJO EXT   680-027-10
# 0RF0482    136.0      0.1496               TRINA NARANJA SLEEK 33CL 24U   680-028-10
# FTZ15B24   92.0       0.1496               FEVERTREE SICILIAN LEMONADE    680-029-10
# 0RF1644    335.0      0.1470               FUZE LSA BIB5L                 680-030-10
# 0RF0189    142.0      0.1470               COCACOLA ZZ PET50 C24 (SIN H   680-031-10
# DL13SR     140.0      0.1470               DAMM LEMON 1/3 SR CAJA 24U.    680-033-10
# 0VE0531    144.0      0.1444               PRIOR  BLANCO VERDEJO 75CL 6   680-034-10
# VE32P6     577.0      0.1417               AGUA VERI 1,5L PET PACK 6U.    680-035-10
# 0AG0053    388.0      0.1417               AQUABONA SINGULAR PET50 C12    680-036-10
# 0RF0043    95.0       0.1417               FANTA LIM PET1L C12            680-037-10
# 0ZU0031    65.0       0.1417               JUVER NECTAR MELOCOTON 20CL    680-038-10
# 0VE2133    296.0      0.1391               MONTERIO TINTO ROSCA 75CL 6U   680-039-10
# 0RF0012    246.0      0.1391               FUENTPINOS GASEOSA  500 PET    680-040-10
# 0ZU0009    76.0       0.1391               GRANINI MELOCOTON 1L PET 6U    680-041-10
# 0ZU0142    229.0      0.1365               MINUTE MAID MAN VNR20 C24      680-042-10
# 0VE0643    139.0      0.1365               RIGOL CAVA BRUT NATURE 75CL    680-043-10
# 0RF0213    255.0      0.1339               MONSTER ENERGY LATA25 C24      600-050-10
# DL13LT     91.0       0.1339               DAMM LEMON 1/3 LATA LC         600-051-10
# 0VE0025    138.0      0.1312               CASTELL D´ORDAL BRUT 75CL 6U   600-052-10
# 0RF1594    154.0      0.1286               AQUARIUS MEL ROJO PET1.5L C6   600-053-10
# 0RF0422    127.0      0.1286               COCA COLA BIB20L               600-054-10
# 0ZU0032    64.0       0.1286               JUVER NECTAR PIÑA 20CL 24U     600-055-10
# 0VE3263    715.0      0.1260               IRREVERENTE VERMUT RESERVA 1   600-056-10
# 0RF0237    139.0      0.1260               RBLISS GINGER ALE VNR20 C24    600-057-10
# GSS1KB6    510.0      0.1234               GARRIGA S.SUPERIOR NATURAL B   600-058-10
# 0RF1350    256.0      0.1207               SPRITE S/A BIB5L               600-059-10
# FTM15B24   120.0      0.1181               FEVERTREE MEDITERRANEAN TONI   600-060-10
# 0RF0221    356.0      0.1155               COCACOLA VNR20 C24             600-061-10
# FDT13LT    84.0       0.1155               FREE DAMM TOSTADA 1/3 LATA L   600-062-10
# 0RF0428    150.0      0.1129               FANTA LIM ZERO BIB 5L          600-063-10
# 0RF0431    105.0      0.1129               FANTA NAR ZER BIB10L (IN)      600-064-10
# 0LT0030    58.0       0.1129               LETONA DESNATADA 0% 1L VR 12   600-065-10
# 0VE0533    120.0      0.1102               PRIOR TINTO TEMPRANILLO 75CL   600-066-10
# 0CF0058    77.0       0.1102               XPLICIT DESCAFEINADO 500GR     600-067-10
# 0RF0253    426.0      0.1076               COCACOLA ZER VNR20 C24         600-068-10
# 0RF0096    157.0      0.1076               POWERADE BLOOD OR PET50 C12    600-069-10
# 0RF0042    103.0      0.1076               FANTA NAR PET1L C12            600-070-10
# 0RF0525    102.0      0.1076               RBLISS GBEER VNR20 C24         600-071-10
# 0AG0039    737.0      0.1050               FONT D.OR NATURAL 1,5L PET 6   600-072-10
# 0RF0214    189.0      0.1024               MONSTER AB. ZERO LATA50 C24    600-073-10
# 0RF1610    188.0      0.1024               FUZE TEA PEACH HIBISCUS PET5   600-074-10
# 0RF0055    187.0      0.1024               NORDIC MIST TON LATA25 C24 E   600-076-10
# 0RF1647    138.0      0.1024               FUZE LSA PET1.5L C6            600-077-10
# 0LT0020    269.0      0.0971               CACAOLAT ORIGINAL 1L PET 6U    600-078-10
# 0AG0009    378.0      0.0945               VICHY CATALAN GAS 1L SR 12U    600-079-10
# 0AG0119    182.0      0.0945               FONT D.OR NATURAL 5L PET 4U    600-080-10
# 0AG0010    178.0      0.0945               VICHY CATALAN GAS 1L RET 12U   600-082-10
# GPA1KB6    245.0      0.0919               GARRIGA S.PURO ARABICA BOLSA   600-083-10
# 0RF0151    94.0       0.0919               AQUARIUS ZER PET1.5L C6        600-084-10
# 0RF0250    81.0       0.0919               APPLETISER VNR275 C24          600-085-10
# 0AG0027    209.0      0.0892               VICHY CATALAN GAS 1/3 LATA 2   600-086-10
# 0RF0236    190.0      0.0892               RBLISS SODA VNR20 C24          600-087-10
# 0RF0232    137.0      0.0866               RBLISS NAR VR20 C24 HT         600-089-10
# 0AM3989    246.0      0.0840               SABOR DEL SUR ACEITE DE OLIV   600-091-10
# 0VE0037    162.0      0.0840               FAUSTINO VII TINTO 75CL 6U     600-092-10
# 0RF1111    68.0       0.0840               JACK AND COKE REG LATA33 C12   600-093-10
# 0VE0197    133.0      0.0814               MONTERIO BLANCO S.R. 75CL 12   600-094-10
# 0RF0231    65.0       0.0814               RBLISS ARO BER VR20 C24        600-095-10
# 1PLV959    37.0       0.0814               VASO IRREVERENTE VERMUT 6U     600-096-10
# VE12TSP    400.0      0.0787               AGUA VERI 1/2 TREKKING 100%R   600-097-10
# CB13SRN    97.0       0.0787               CARLSBERG 1/3 SR CAJA 24U.     600-098-10
# 0RF0503    95.0       0.0787               COCACOLA ZER ZER BIB5L         600-099-10
# ED14P6     76.0       0.0787               ESTRELLA DAMM 1/4 PACK SEMIC   600-100-10
# 0VE0949    37.0       0.0787               AC COSTA DAS DORNAS 75CL 12U   600-101-10
# UE112N     2114.0     0.0761               JARRA EPOCA 0,5 L ED           600-102-10
# 0VE0663    125.0      0.0761               FAUSTINO ART COLLECTION CRIA   600-103-10
# 0AG0084    92.0       0.0761               SAN PELLEGRINO GAS 1L PET 6U   600-104-10
# 0RF0061    78.0       0.0761               POWERADE CITRUS CH PET50 C12   600-106-10
# 0RF0220    188.0      0.0735               MONSTER REHAB LEMON LATA50 C   600-108-10
# 0RF0576    73.0       0.0735               RED BULL SUGAR FREE 25CL LAT   600-110-10
# 0RF0292    33.0       0.0735               /-FANTA NARANJA VR237 24U      600-112-10
# 0RF0293    30.0       0.0735               /-FANTA LIMON VR237 24U        600-114-10
# VE11SPC    221.0      0.0709               AGUA VERI 1/1 PET CAJA 12U.    600-116-10
# 0AG0052    143.0      0.0709               VICHY CATALAN GAS 1/2 PET 24   630-001-10
# FTP154BF   44.0       0.0709               FEVERTREE PINK GRAPEFR.1/5 B   630-002-10
# 0RF1595    33.0       0.0709               AQUARIUS MEL ROJO LATA33 C24   630-003-10
# GPT1KB6    201.0      0.0682               GARRIGA PURO ARABICA 1KG TUE   630-004-10
# 0AG0030    166.0      0.0682               VILAS TURBON AGUA PET50 C24    630-005-10
# 0VE0041    120.0      0.0682               FAUSTINO CRIANZA TINTO 75CL    630-006-10
# 0VE00464   59.0       0.0682               SOLAR DE ZUNIL ROSADO 75CL 6   630-007-10
# 0AM1286    51.0       0.0682               BARGASOL OLI ALT OLEIC EXTRA   630-008-10
# 0AM1283    42.0       0.0682               BARGALLO OLI FRIT FRIT 25L     630-009-10
# 0RF0063    34.0       0.0682               BURN LATA25 C24                630-010-10
# NTY32SP6   78.0       0.0656               NESTEA TE VERDE MARACUYA 3/2   630-011-10
# 0AG0105    68.0       0.0656               VICHY CATALAN GAS 1/2 SR 20U   630-012-10
# VO13LT     52.0       0.0656               VOLL DAMM 1/3 LATA LC          630-013-10
# 0AG0031    668.0      0.0630               VILAS TURBON AGUA PET1L C6     630-014-10
# 0RF0106    189.0      0.0630               FANTA ZER NAR LATA33 C24       630-015-10
# 0LT0091    47.0       0.0630               LETONA SEMI ESP.HOST.1L VR 1   630-016-10
# 0RF1356    44.0       0.0630               MONSTER ULTRA PEACHY KEEN LA   630-017-10
# 0RF0210    39.0       0.0630               MONSTER ENERGY LATA553 C12     630-018-10
# 0RF0088    34.0       0.0630               /-SCHWEPPES TONICA LATA SLEE   630-019-10
# UE115      1314.0     0.0604               VASO EPOCA 25 CL ED            630-020-10
# 0RA0040    89.0       0.0604               VINYES BON CEP SANGRIA BOX 1   630-022-10
# 0RF0156    30.0       0.0604               BURN LATA50 C12                630-023-10
# 0AG0090    550.0      0.0577               FONT D.OR NATURAL 1/3 LATA 2   630-024-10
# 0RF0423    26.0       0.0577               /-SPRITE VR20 24U              630-025-10
# FTI14LTB   129.0      0.0551               FEVERTREE INDIAN TONIC 1/4 L   630-026-10
# 0VE1409    90.0       0.0551               ALLUE CAVA BRUT 75CL 6U        630-027-10
# 0RF0491    33.0       0.0551               SCHWEPPES LIMON 20CL SR 24U    630-028-10
# 0VE0542    30.0       0.0551               IRREVERENTE TINTO JOVEN 75CL   630-029-10
# 0RF1623    27.0       0.0551               LIMCA PET50 C24                630-030-10
# 0ZU0117    25.0       0.0551               JUVER NECTAR NARANJA 20CL 24   630-031-10
# 0RF0496    78.0       0.0525               AQUARIUS ZERO BIB5L            630-032-10
# 0RF0548    76.0       0.0525               SPRITE VNR20 P4 C6             630-033-10
# 0VE0403    52.0       0.0525               MARQUES VITORIA CRIANZA 75CL   630-034-10
# 0RF0348    29.0       0.0525               MONSTER ULTRA PARADISE LATA5   630-035-10
# DM13P6     23.0       0.0525               DAURA MARZEN 1/3SR PACK CEST   630-036-10
# 0RF0807    117.0      0.0499               FANTA SANDÍA S/AZ PET50 C24    630-037-10
# 0RF0102    56.0       0.0499               AQUARIUS ZER LATA33 C24        630-038-10
# 0RF0165    47.0       0.0499               COCACOLA ZER ZER PET2L C6      630-039-10
# 0AG0023    41.0       0.0499               AQUABONA SINGULAR VR365 C20    630-040-10
# 0RF1098    33.0       0.0499               MONSTER HAMILTON ZERO LATA50   630-041-10
# 0AG0015    146.0      0.0472               AQUABONA VR1L C12              630-042-10
# FTP15B24   48.0       0.0472               FEVERTREE PINK GRAPEFRUIT. 1   630-043-10
# 0VE2202    47.0       0.0472               TORRACOLLONS TINTO 75CL 6U     630-045-10
# 0VE0466    37.0       0.0472               NAIADA BLANCO 75CL 6U          630-046-10
# GSE1KB6    172.0      0.0446               GARRIGA S.EXPRES NATURAL BOL   630-047-10
# 0VE1004    162.0      0.0446               CAMPILLO TINTO CRIANZA 75CL    630-048-10
# 0AG0431    143.0      0.0446               MONTE PINOS NATURAL RING PUL   630-049-10
# 0RF0544    116.0      0.0446               FANTA LIM VNR20 P4 C6          630-050-10
# 0RF0122    59.0       0.0446               MONSTER ULTRA RED LATA50 C24   630-051-10
# 0RF0117    48.0       0.0446               COCACOLA LIG LATA33 C24        630-052-10
# 0RF1147    45.0       0.0446               RBLISS BIT ROS VNR20 C24       630-053-10
# 0RF0152    43.0       0.0446               AQUARIUS NAR ZER PET1.5L C6    630-054-10
# 0AM3376    24.0       0.0446               BARGALLO ACEITE ALTO RENDIMI   660-044-10
# 0RF1357    26.0       0.0420               MONSTER ULTRA ROSA LATA50 C2   660-045-10
# UE903CATN  792.0      0.0394               COPA 20 CL ED CAT              660-046-10
# 0RF0468    102.0      0.0394               COCACOLA BIB10L                660-047-10
# 0AG0028    98.0       0.0394               VILAS TURBON AGUA VNR33 C24    660-048-10
# NTL12P24   55.0       0.0394               NESTEA LIMON 1/2 SR PET 24U.   660-049-10
# 0VE0666    46.0       0.0394               PORTIA VERDEJO 75CL 6U         660-050-10
# UE050CATN  1500.0     0.0367               VASO GASTRO 25 CL ED CAT       660-051-10
# 0RF0537    332.0      0.0367               COCACOLA ZER LATA20 P6         660-052-10
# 0AG0335    88.0       0.0367               FONT SUBIRA NATURAL 20L GARR   660-053-10
# 0RF0103    48.0       0.0367               AQUARIUS NAR ZER LATA33 C24    660-054-10
# 0ZU0136    19.0       0.0367               MINUTE MAID TOM VNR20 C24      660-055-10
# UC403CATN  630.0      0.0341               SERVILLETERO ED CAT            660-056-10
# 0RF0598    85.0       0.0341               MONSTER ULTRA FIESTA LATA50    660-057-10
# 0RF1589    57.0       0.0341               MONSTER JUICE BAD APPLE LATA   660-058-10
# 0VE0636    55.0       0.0341               SANTANA TINTO TEMPRANILLO 75   660-059-10
# VI30       33.0       0.0341               VICTORIA BARRIL 30L.           660-060-10
# TU13LT     23.0       0.0341               TURIA 1/3 LATA                 660-061-10
# 0RF0679    22.0       0.0341               COCACOLA ZER LIME LATA33 CCO   660-062-10
# 0RF0437    14.0       0.0341               /-NESTEA LIM VR30 24U          660-063-10
# UE113N     1002.0     0.0315               JARRA EPOCA 0,3 L ED           660-064-10
# 0RF0235    38.0       0.0315               RBLISS TON WTR VNR20 C24       660-065-10
# XI11SRB6   36.0       0.0315               XIBECA 1/1 SR BANDEJA 6U.      660-066-10
# 0RF0532    30.0       0.0315               ROYAL BLISS YUZ VNR20 C24      660-067-10
# 0RF0240    28.0       0.0315               POWERADE ZER ICE STORM PET50   660-068-10
# 0RF1590    25.0       0.0315               JACK AND COKE ZER S/CAF LATA   660-069-10
# 0RF1651    15.0       0.0315               FUZE LSA VR30 C24              660-070-10
# 0AG0046    76.0       0.0289               VICHY CATALAN GAS 1,2L PET 6   660-071-10
# 0VE0474    54.0       0.0289               EL NIÑO DE CAMPILLO 75CL 6U    660-072-10
# 0AM1277    29.0       0.0289               BARGALLO ACEITE OLIVA INTENS   660-073-10
# EDI34SR    29.0       0.0289               INEDIT DAMM 3/4 SR CAJA 12U.   660-074-10
# 0AM1284    19.0       0.0289               BARGALLO OLI FRIT FRIT 10L     660-075-10
# FTR15B24   16.0       0.0289               FEVERTREE RASPBERRY 1/5 BJ-2   660-076-10
# 0RF0149    12.0       0.0289               FANTA ZER LIM LATA33 C24       660-077-10
# 0RF0882    396.0      0.0262               SPRITE ZER LATA33 C24 CCO8     660-079-10
# 0VE0095    106.0      0.0262               PORTIA CRIANZA 75CL 6U         660-080-10
# 0AM1168    82.0       0.0262               MARINAS PATATAS PIMIENTA VIN   660-081-10
# UE931CATN  48.0       0.0262               PIZARRA PARED ED               660-082-10
# GBD20      13.0       0.0262               GRIMBERGEN DOUBLE AMBREE BAR   660-083-10
# 0RF0896    11.0       0.0262               MONSTER KHAOTIC JUICE LATA50   660-084-10
# 1PLV0500   480.0      0.0236               VASO 50CL 70W CC CUP (50) ES   660-085-10
# 0RF1070    69.0       0.0236               RED BULL WATER MELON 25CL LA   660-087-10
# 0RF1074    37.0       0.0236               RED BULL COCO Y ARANDANOS LT   660-088-10
# 0ZU0138    35.0       0.0236               MINUTE MAID UVA VNR20 C24      660-089-10
# 0ZU0729    24.0       0.0236               NEKTAR GOLD PREMIUM ORANGE P   660-090-10
# NTS32SP6   20.0       0.0236               NESTEA LIMON SIN 3/2 SR PET    660-091-10
# 1PLV0501   260.0      0.0210               VASO 75CL 32oz CC CUP (50) E   660-092-10
# 0AG0029    212.0      0.0210               VILAS TURBON AGUA VNR75L C6    660-093-10
# 0RF0535    178.0      0.0210               COCACOLA LATA20 P6             660-094-10
# 0RF1665    16.0       0.0210               ROYAL BLISS POMELO VNR20 C24   660-095-10
# 0RF1633    15.0       0.0210               COCACOLA ZER LATA33 P6         660-096-10
# 0RF0897    8.0        0.0210               MONSTER ULTRA WATERMELON LT5   680-044-10
# 0ZU0445    16.0       0.0184               NEKTAR GOLD MANGO TUBE BIB 8   680-045-10
# 0RF0870    10.0       0.0184               FANTA SANDIA S/AZ LATA33 C24   680-046-10
# UE962CAT   550.0      0.0157               ABRIDOR ED CAT                 680-047-10
# 0RF1683    363.2      0.0157               MONSTER JUICED RIO PUNCH LT5   680-048-10
# 1PLV214    240.0      0.0157               TAPA VASO 40/50 cl 100u        680-049-10
# 0CZ0159    168.0      0.0157               GUINNESS BARRIL 30L            680-050-10
# 0VE2468    41.0       0.0157               FAUSTINO I GRAN RESERVA 75CL   680-051-10
# 0VE1081    25.0       0.0157               NAIADA TINTO 75CL 6U           680-052-10
# 0ZU0451    20.0       0.0157               NEKTAR SILVER PREMIUM ORANGE   680-053-10
# 0RF0006    12.0       0.0157               FUENTPINOS GASEOSA 50CL RET    680-054-10
# FDL13LT    10.0       0.0157               FREE DAMM LIMON 1/3 LATA       680-055-10
# 0RF0024    7.0        0.0157               COCACOLA SCF LATA33 C24        680-056-10
# 0RF1675    363.0      0.0131               MONSTER ULTRA STWBERRY DREAM   680-058-10
# UVD105     300.0      0.0131               COPA 33 CL VD                  680-059-10
# 1PLV0098   73.0       0.0131               COPA VINO FAUSTINO 6U          680-060-10
# 0VE1064    38.0       0.0131               MARQUES VITORIA VERDEJO 75CL   680-062-10
# 0AM1499    21.0       0.0131               BARGASOL ACEITE GIRASOL ALTO   680-063-10
# 0ZU0457    8.0        0.0131               NEKTAR VITA GREEN APPEL+LEMO   680-064-10
# FTM15C4B   8.0        0.0131               FEVERTREE MEDITERRAN. TONIC    680-065-10
# 0RF1611    5.0        0.0131               FUZE TEA PEACH HIBISCUS PET1   680-066-10
# 1PLV212    220.0      0.0105               VASO 40 CL 50W CC CUP (50)     680-067-10
# 0AG0370    120.3      0.0105               FONT D'OR PALLADIUM 1/3 LATA   680-068-10
# 0RF0434    38.0       0.0105               NORDIC MIST TON BIB5L          680-069-10
# 0AG0136    11.0       0.0105               MONTE PINOS NATURAL 1/3 SR 2   680-070-10
# RB30       5.0        0.0105               ROSA BLANCA BARRIL 30L.        680-071-10
# 0VE0712    4.0        0.0105               FER VOLAR COLOMS D.O.CATALUN   680-073-10
# 0RA0004    4.0        0.0105               DON SIMON SANGRIA 1,5L 6U      680-074-10
# 0RF0617    157.0      0.0079               BURN ZERO RASPBERRY LATA50 C   680-075-10
# 1PLV217    66.0       0.0079               TAPA VASO 75 cl 100u           680-076-10
# 0AG0131    57.0       0.0079               MONTE PINOS NATURAL 1/3 PET    680-079-10
# 0RF0616    19.0       0.0079               BURN ZERO PEACH LATA50 C12     680-080-10
# 0RF0097    3.0        0.0079               COCACOLA PET2L P2 C3           680-081-10
# 1PLV202    3.0        0.0079               GRANINI NEVERA PREM 3 ALT BA   680-083-10
# 0RF0065    38.0       0.0052               COCA COLA LSC LATA33 C24       680-084-10
# 0AM2163    24.0       0.0052               GALLINA BLANCA TOMATE TAMIZA   680-087-10
# FTG15C4B   22.0       0.0052               FEVERTREE GINGER ALE 1/5 BJ-   680-090-10
# 0AG0424    19.0       0.0052               MONTE PINOS NATURAL RING PUL   680-091-10
# 0AG0129    11.0       0.0052               MONTE PINOS NATURAL 1,5L PET   680-092-10
# 0VE0510    8.0        0.0052               VALDUBON VERDEJO BLANC 75CL    690-002-10
# 0RF1001    3.0        0.0052               MONSTER RESERVE WHITE PINEAP   690-004-10
# 0VE1080    3.0        0.0052               NAIADA ROSADO 75CL 6U          690-008-10
# 0RF0599    2.0        0.0052               MONSTER MONARCH LATA50 C24     690-009-10
# 0ZU0444    2.0        0.0052               NEKTAR GOLD PINEAPLLE TUBE B   690-011-10
# UE926CATN  500.0      0.0026               POSAVASOS ED CAT               690-012-10
# UT302X     312.0      0.0026               COPA 33 CL TU P                690-014-10
# UE975T     200.0      0.0026               VASO PAPEL ED 33CL             690-015-10
# 1PLV0034   120.0      0.0026               SERVILLETERO CACAOLAT          690-017-10
# 1PLV0205   100.0      0.0026               FAUSTINO MANGA ENFRIADORA      690-019-10
# UV020X     60.0       0.0026               SERVILLETERO METALICO VO       690-022-10
# UT302      60.0       0.0026               COPA 30 CL TURIA               690-025-10
# 0RF1622    39.0       0.0026               LIMCA PET1L C12                690-026-10
# UC406N     34.0       0.0026               ABRIDOR MOSTRADOR ED           690-027-10
# FTS1524B   12.0       0.0026               FEVERTREE SODA WATER 1/5 BAN   690-028-10
